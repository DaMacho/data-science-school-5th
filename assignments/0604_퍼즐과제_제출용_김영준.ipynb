# %%
# -*- coding: utf-8 -*-

import random

# puzzle을 아래와 같이 보기좋은 모양으로 출력함
# 1 2 3
# 4 5 6
# 7 8
def show_puzzle(puzzle):
    for row in puzzle:
        for col in row:
            print col,
        print

# 퍼즐을 생성한다.
# 퍼즐은 동적으로 생성되며, 2차원 리스트 형태를 갖는다
# 즉 [[1, 2, 3], [4, 5, 6], [7, 8, '']]
# 빈공간은 ''로 표현한다
def initiate_puzzle(size):
    size_num = [3, 4, 5]
    if size in size_num:
        size = range(1, size**2)
        size.append('')

        size1 = []

        if len(size) == 9:
            size1.append(size[:3])
            size1.append(size[3:6])
            size1.append(size[6:9])
        elif len(size) == 16:
            size1.append(size[:4])
            size1.append(size[4:8])
            size1.append(size[8:12])
            size1.append(size[12:])
        else:
            size1.append(size[:5])
            size1.append(size[5:10])
            size1.append(size[10:15])
            size1.append(size[15:20])
            size1.append(size[20:])

        puzzle = size1

        return puzzle
    else:
        return 'Please input only 3, 4 or 5'

# 퍼즐을 랜덤하게 섞음
def shuffle_puzzle(puzzle):
    dxs = [1, 0, -1,  0]
    dys = [0, 1,  0, -1]

    cnt = 0
    while cnt <= 300:
        rnd = random.randint(0, 3)
        dx = dxs[rnd]
        dy = dys[rnd]

        i, j = get_index(puzzle, '')
        ni = i + dx
        nj = j + dy

        if 0 <= ni < len(puzzle) and 0 <= nj < len(puzzle[0]):
            puzzle[ni][nj], puzzle[i][j] = puzzle[i][j], puzzle[ni][nj]
        cnt += 1

# 퍼즐이 종료되었는지, 즉 차례대로 정렬되어 완료가 되었는지 검사
def is_done(puzzle, complete):
    if puzzle == complete:
        return True
    else:
        False


# 퍼즐 보드에서 숫자 n의 인덱스 검색
# 2차원이기 때문에 i, j형태의 인덱스 값을 반환
def get_index(puzzle, n):
    i , j = 0,0
    for i in range(size):
        for j in range(size):
            if puzzle[i][j] == n:
                return i,j
        
                

# 퍼즐에서 숫자 n을 이동,
# 이동할 수 없는 경우에는 이동할 수 없다고 표시
# 이동이 가능한 경우는 양옆위아래에 ''가 위치해 있을 경우이다
def move_by_number(puzzle, n):
    get_index(puzzle, n)
    move_by_index(puzzle, i, j)
    
    if puzzle[i+1][j] == '':
        puzzle[i+1][j] = temp
    elif puzzle[i-1][j] == '':
        puzzle[i-1][j] = temp
    elif puzzle[i][j+1] == '':
        puzzle[i][j+1] = temp
    elif puzzle[i][j-1] == '':
        puzzle[i][j-1] = temp
    else:
        print 'you cannot move that number, insert other number movable'

    puzzle[i][j] = ''


# 숫자를 이동시키기 위해서는 결국 인덱스를 알아야 함
# 즉 move_by_number 내부에서 호출되는 함순
def move_by_index(puzzle, i, j):
    # movable condition
    # 좌우위아래 한방향중 하나가 '' 값이라면 이동 가능
    if puzzle[i+1][j] == '' or puzzle[i-1][j] == '' or puzzle[i][j+1] == '' or puzzle[i][j-1] == '':
        temp = puzzle[i][j]
        return temp


# 퍼즐 생성
size = int(raw_input(' -> please insert puzzle size : '))
puzzle = initiate_puzzle(size)

# 연습문제) -> 아래와 같이 복사하는 이유는?
complete = [row[:] for row in puzzle]

# 퍼즐 섞기
shuffle_puzzle(puzzle)

# 섞인 퍼즐 보기
show_puzzle(puzzle)

# 퍼즐 풀기
while not is_done(puzzle, complete):
    num = int(raw_input(' -> select a number to move : '))
    # 움직일 수 선택하기
    move_by_number(puzzle, num)

    # 화면 clear
    import os
    cls = lambda: os.system('clear') # windows cls
    cls()

    # 움직인 이후 퍼즐 상태 보기
    show_puzzle(puzzle)

print '\nyou solved the puzzle!'
# Out:
#  -> please insert puzzle size : 4
#  2 4 11
# 1 5 8 3
# 9 7 12 15
# 13 14 10 6
#  -> select a number to move : 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-966d8a7de1bb> in <module>()
#     133     num = int(raw_input(' -> select a number to move : '))
#     134     # 움직일 수 선택하기
# --> 135     move_by_number(puzzle, num)
#     136
#     137     # 화면 clear
#
# <ipython-input-5-966d8a7de1bb> in move_by_number(puzzle, n)
#      90 def move_by_number(puzzle, n):
#      91     get_index(puzzle, n)
# ---> 92     move_by_index(puzzle, i, j)
#      93
#      94     if puzzle[i+1][j] == '':
#
# NameError: global name 'i' is not defined
